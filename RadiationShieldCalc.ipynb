# %%
import math
import tkinter as tk
from tkinter import messagebox
#print("\033[31mEste texto está en rojo\033[0m")

def kerma_total (N,U,k_p,d_p):
    # N es el numero promedio de pacientes examinados a la semana
    # U es el factor de uso
    K_t = (k_p * N * U)/(d_p ** 2)
    return K_t
N=float(input("ingrese el número promedio de pacientes examinados a la semana "))
d_p=float(input("ingrese el la distancia de la fuente a la barrera "))
U=float(input("ingrese el factor de uso ") )
print("\033[31mIngrese el tipo de zona\033[0m ")
print("1. Area controlada")
print("2. Area sin controlar")
P_usuario=input()
if P_usuario=="1":
  P=0.1
elif P_usuario=="2":
  P=0.02


def transmision_maxima (P,T):
    B_p= P/(T * result_kerma_total)
    return B_p

def ancho_barrera (alfa, beta, gamma):
    x_b = (1/(alfa * gamma)) * math.log((((1/Trans_maxima)**gamma)+(beta/alfa))/(1+(beta/alfa)))
    return x_b

tabla_coeficientes_barrera_primaria = tabla_traducida = [
    {"Material": "Plomo", "Barrera": "Todas las barreras", "Alpha (α)": 2.298, "Beta (β)": 17.38, "Gamma (γ)": 6.193e-1},
    {"Material": "Plomo", "Barrera": "Bucky de tórax", "Alpha (α)": 2.256, "Beta (β)": 13.80, "Gamma (γ)": 8.837e-1},
    {"Material": "Plomo", "Barrera": "Suelo/Otros", "Alpha (α)": 2.513, "Beta (β)": 17.34, "Gamma (γ)": 4.994e-1},
    {"Material": "Concreto", "Barrera": "Todas las barreras", "Alpha (α)": 3.610e-2, "Beta (β)": 1.433e-1, "Gamma (γ)": 5.600e-1},
    {"Material": "Concreto", "Barrera": "Bucky de tórax", "Alpha (α)": 3.560e-2, "Beta (β)": 1.079e-1, "Gamma (γ)": 7.705e-1},
    {"Material": "Concreto", "Barrera": "Suelo/Otros", "Alpha (α)": 3.920e-2, "Beta (β)": 1.464e-1, "Gamma (γ)": 4.486e-1},
    {"Material": "Yeso", "Barrera": "Todas las barreras", "Alpha (α)": 1.380e-2, "Beta (β)": 5.700e-2, "Gamma (γ)": 7.937e-1},
    {"Material": "Yeso", "Barrera": "Bucky de tórax", "Alpha (α)": 1.270e-1, "Beta (β)": 4.450e-2, "Gamma (γ)": 1.049},
    {"Material": "Yeso", "Barrera": "Suelo/Otros", "Alpha (α)": 1.640e-2, "Beta (β)": 6.080e-2, "Gamma (γ)": 7.472e-1},
]








print("\033[31mMaterial de la barrera\033[0m ")
print("1. Plomo - Todas las barreras")
print("2. Plomo - Bucky de tórax")
print("3. Plomo - Suelo/Otros")
print("4. Concreto - Todas las barreras")
print("5. Concreto - Bucky de tórax")
print("6. Concreto - Suelo/Otros")



q=input("Elija el material de la barrera ")
if q=="1":
  alfa=2.346
  beta=15.90
  gamma=0.4982

elif q=="2":
  alfa=2.264
  beta=13.08
  gamma=0.5600
elif q=="3":
  alfa=2.651
  beta=16.56
  gamma=0.4585
elif q=="4":
  alfa=0.03626
  beta=0.1429
  gamma=0.4932
elif q=="5":
  alfa=0.03552
  beta=0.1177
  gamma= 0.6007
elif q=="6":
  alfa=0.03994
  beta=0.1448
  gamma=0.4231


tabla_factor_uso_primario = [
       {
        "1": 0.89,
        "2": 0.09,
        "3": 0.02,
        "4": 1.00
      }
]
print( "\033[31mTipos de barrea\033[0m")
print("1. Piso")
print("2. Mesa-pared")
print("3. Pared")
print("4. receptor de imágenes de tórax")
x= input("Introduce el tipo de barrera para calcular su blindaje:")
factor_uso_primario = tabla_factor_uso_primario[0][x]



print("\033[31mElija el lugar para el factor de ocupación\033[0m")
print("1. zonas de juego de niños, salas de rayos X adyacentes, zona de lectura de películas, controles de enfermería y de salas de rayos X")
print("2. Salas de tratamiento o de examen de pacientes")
print("3. Pasillos, habitaciones de pacientes, salas de descanso del personal y vestuarios")
print("4. Puertas de pasillos")
print("5. Servicios, salas de almacén, zonas exteriores con bancos, salas de espera sin asistentes")
print("6. Zonas exteriores con peatones y tráfico rodado, zonas de aparcamiento sin vigilante, áticos, escaleras, ascensores no atendidos")
tabla_ocupacion_T = [
    {"1": 1,
     "2": 1/2,
     "3": 1/5,
     "4": 1/8,
     "5": 1/20,
     "6": 1/40}
]
y=input("")
T=tabla_ocupacion_T[0][y]


tabla_xpre = [
    {
        "Aplicación": "Receptor de imagen en la mesa o pared: chasis + rejilla + soportes del receptor de imagen",
        "1": 0.85,
        "2": 72,
        "3": 7,
        "Aplicación": "Cross-table (rejilla + chasis)",
        "4": 0.3,
        "5": 30,
        "6": 2
    }
]
print("\033[31mOpciones para xpre\033[0m ")
print("Aplicación Receptor de imagen en la mesa o pared: chasis + rejilla + soportes del receptor de imagen")
print("1. Plomo (mm)")
print("2. Hormigón (mm)")
print("3. Acero (mm)")
print(" Aplicación" "Cross-table (rejilla + chasis)")
print("4. Plomo (mm)")
print("5. Hormigón (mm)")
print("6. Acero (mm)")

z=input("Elija xpre ")
xpre = tabla_xpre[0][z]

#tabla_workload_distribution = [
   # {

     # "Workload Distribution""Rad Room (chest bucky)",
     #  "W_norm (mA min patient^-1)" 0.6,
      #  "K'_p (mGy patient^-1)" 2.3,

      #  "Workload Distribution""Rad Room (floor or other barriers)",
      #  "W_norm (mA min patient^-1)" 1.9,
        #"K'_p (mGy patient^-1)" 5.2,

      #  "Workload Distribution" "Rad Tube (R&F Room)",
       # "W_norm (mA min patient^-1)" 1.5,
       # "K'_p (mGy patient^-1)" 5.9,

      #  "Workload Distribution" "Chest Room",
       # "W_norm (mA min patient^-1)" 0.22,
       # "K'_p (mGy patient^-1)" 1.2
   # }
#]

print("\033[31mDistribución de carga de trabajo\033[0m ")
print("1. Distribución de carga de trabajo - Sala de radiografía (Bucky de tórax)")
print("2. Distribución de carga de trabajo - Sala de radiografía (Suelo u otras barreras)")
print("3. Distribución de carga de trabajo - Tubo de rayos X (Sala R&F)")
print("4. Distribución de carga de trabajo - Sala de tórax")

u=input("Elija Workload distribution")
if u=="1":
  W_norm=0.6
  k_p=2.3
elif u=="2":
  W_norm=1.9
  k_p=5.2
elif u=="3":
  W_norm=1.5
  k_p=5.9
elif u=="4":
  W_norm=0.22
  k_p=1.2

result_kerma_total=kerma_total (N,U,k_p,d_p)

Trans_maxima=transmision_maxima (P,T)

print("El valor de la constante T es:", T)
print("Valor del factor de uso primario:", factor_uso_primario)
print("Valor de xpre:", xpre)
print("valor constante k_p:", k_p)
print("El valor del kerma total es: ",result_kerma_total)
print("El valor de la transmición máxima es: ",Trans_maxima)
resultado_x_b= ancho_barrera (alfa, beta, gamma)
grosor = resultado_x_b - xpre
print("\033[31mResultado ancho de la barrera en mm sin tener en cuenta la dispersion de por el receptor de imagen es: {:.2f} \033[0m".format(resultado_x_b))
print("\033[31mResultado ancho de la barrera en mm es: {:.2f} \033[0m".format(grosor))
#tipo_barrera = str(input("Introduce el tipo de barrera para calcular su blindaje: "))
#material_barrera = str(input("Introduce el tipo de material para calcular su blindaje: "))
#ocupacion = str(input("Introduce la ocupación de la sala: "))
#numero_pasientes = int(input("Introduce el número de pacientes que esperan en la sala: "))
# Out:
# ingrese el número promedio de pacientes examinados a la semana 125
# ingrese el la distancia de la fuente a la barrera 4.1
# ingrese el factor de uso 1
# Ingrese el tipo de zona
# 1. Area controlada
# 2. Area sin controlar
# 2
# Material de la barrera
# 1. Plomo - Todas las barreras
# 2. Plomo - Bucky de tórax
# 3. Plomo - Suelo/Otros
# 4. Concreto - Todas las barreras
# 5. Concreto - Bucky de tórax
# 6. Concreto - Suelo/Otros
# Elija el material de la barrera 6
# Tipos de barrea
# 1. Piso
# 2. Mesa-pared
# 3. Pared
# 4. receptor de imágenes de tórax
# Introduce el tipo de barrera para calcular su blindaje:1
# Elija el lugar para el factor de ocupación
# 1. zonas de juego de niños, salas de rayos X adyacentes, zona de lectura de películas, controles de enfermería y de salas de rayos X
# 2. Salas de tratamiento o de examen de pacientes
# 3. Pasillos, habitaciones de pacientes, salas de descanso del personal y vestuarios
# 4. Puertas de pasillos
# ...

# %%
#PARA BARRERA SECUNDARIA
import math
import tkinter as tk
from tkinter import messagebox
tabla_plomo = [
    {"Distribución de carga de trabajo": "150 kVp", "Alpha (α)": 1.791, "Beta (β)": 5.478, "Gamma (γ)": 5.678},
    {"Distribución de carga de trabajo": "Sala de radiografía (todas las barreras)", "Alpha (α)": 3.859, "Beta (β)": 13.81, "Gamma (γ)": 8.332},
    {"Distribución de carga de trabajo": "Sala de radiografía (Bucky de tórax)", "Alpha (α)": 1.38, "Beta (β)": 8.304, "Gamma (γ)": 8.837},
    {"Distribución de carga de trabajo": "Sala de radiografía (suelo u otras barreras)", "Alpha (α)": 2.513, "Beta (β)": 1.734, "Gamma (γ)": 4.994},
]

tabla_concreto = [
    {"Distribución de carga de trabajo": "Sala de radiografía (todas las barreras)", "Alpha (α)": 0.05094, "Beta (β)": 7.7, "Gamma (γ)": 1.566},
    {"Distribución de carga de trabajo": "Sala de radiografía (Bucky de tórax)", "Alpha (α)": 0.0381, "Beta (β)": 8.1, "Gamma (γ)": 1.586},
    {"Distribución de carga de trabajo": "Sala de radiografía (suelo u otras barreras)", "Alpha (α)": 0.04219, "Beta (β)": 7.499, "Gamma (γ)": 1.472},
]


#K_sec = [
  #  {
       # "1": 3.4e-2,

     #   "2": 4.9e-3,

      #  "3": 2.3e-2,
   # }
#]
print("\033[31mElija el tipo de barrera\033[0m")
print("1. Todas las barreras")
print("2. Bucky de tórax")
print("3. Suelo u otras barreras")
w=input(" ")
if w=="1":
  K_secc=3.4e-2
elif w=="2":
  K_secc=5.3e-3
elif w=="3":
  K_secc=2.3e-2



d_p=float(input("ingrese el valor de d_p "))
print("\033[31mIngrese el tipo de zona\033[0m")
print("1. Area controlada")
print("2. Area sin controlar")
P_usuario=input()
if P_usuario=="1":
  P=0.1
elif P_usuario=="2":
  P=0.02


print("\033[31mMaterial de la barrera\033[0m ")
print("1. Plomo - Todas las barreras")
print("2. Plomo - Bucky de tórax")
print("3. Plomo - Suelo/Otros")
print("4. Concreto - Todas las barreras")
print("5. Concreto - Bucky de tórax")
print("6. Concreto - Suelo/Otros")
print("7. Yeso - Todas las barreras")
print("8. Yeso - Bucky de tórax")
print("9. Yeso - Suelo/Otros")


q=input("Elija el material de la barrera")
if q=="1":
  alfa=2.298
  beta=17.38
  gamma=6.193e-1

elif q=="2":
  alfa=2.256
  beta=13.80
  gamma=8.837e-1
elif q=="3":
  alfa=2.513
  beta=17.34
  gamma=4.994e-1
elif q=="4":
  alfa=3.610e-2
  beta=1.433e-1
  gamma=5.600e-1
elif q=="5":
  alfa=3.560e-2
  beta=1.079e-1
  gamma= 7.705e-1
elif q=="6":
  alfa=3.920e-2
  beta=1.464e-1
  gamma=4.486e-1
elif q=="7":
  alfa=1.380e-2
  beta=5.700e-2
  gamma=7.937e-1
elif q=="8":
  alfa=1.270e-1
  beta= 4.450e-2
  gamma=1.049
elif q=="9":
  alfa=1.640e-2
  beta=6.080e-2
  gamma= 7.472e-1


print("\033[31mElija el lugar para el factor de ocupacion\033[0m ")
print("1. zonas de juego de niños, salas de rayos X adyacentes, zona de lectura de películas, controles de enfermería y de salas de rayos X")
print("2. Salas de tratamiento o de examen de pacientes")
print("3. Pasillos, habitaciones de pacientes, salas de descanso del personal y vestuarios")
print("4. Puertas de pasillos")
print("5. Servicios, salas de almacén, zonas exteriores con bancos, salas de espera sin asistentes")
print("6. Zonas exteriores con peatones y tráfico rodado, zonas de aparcamiento sin vigilante, áticos, escaleras, ascensores no atendidos")
tabla_ocupacion_T = [
    {"1": 1,
     "2": 1/2,
     "3": 1/5,
     "4": 1/8,
     "5": 1/20,
     "6": 1/40}
]
y=input("")
T=tabla_ocupacion_T[0][y]

print("\033[31mElija el número de pacientes\033[0m")
N = int(input(" "))

def kerma_aire(N,K_sec, d_p):
  ksec_0 =(K_sec * N)/ (d_p ** 2)
  return ksec_0

kermaInAire = kerma_aire (N,K_secc, d_p)


def transmision_maxima (P,T):
    B_p= P/(T * kermaInAire)
    return B_p

Trans_maxima = transmision_maxima (P,T)


Trans_maxima=transmision_maxima (P,T)
def ancho_barrera (alfa, beta, gamma):
    x_b = (1/(alfa * gamma)) * math.log((((1/Trans_maxima)**gamma)+(beta/alfa))/(1+(beta/alfa)))
    return x_b


resultado_x_b= ancho_barrera (alfa, beta, gamma)
print("\033[31mResultado ancho de la barrera en mm es: {:.2f} \033[0m".format(resultado_x_b))
# Out:
# Elija el tipo de barrera
# 1. Todas las barreras
# 2. Bucky de tórax
# 3. Suelo u otras barreras
#  1
# ingrese el valor de d_p 2.7
# Ingrese el tipo de zona
# 1. Area controlada
# 2. Area sin controlar
# 2
# Material de la barrera
# 1. Plomo - Todas las barreras
# 2. Plomo - Bucky de tórax
# 3. Plomo - Suelo/Otros
# 4. Concreto - Todas las barreras
# 5. Concreto - Bucky de tórax
# 6. Concreto - Suelo/Otros
# 7. Yeso - Todas las barreras
# 8. Yeso - Bucky de tórax
# 9. Yeso - Suelo/Otros
# Elija el material de la barrera4
# Elija el lugar para el factor de ocupacion
# 1. zonas de juego de niños, salas de rayos X adyacentes, zona de lectura de películas, controles de enfermería y de salas de rayos X
# 2. Salas de tratamiento o de examen de pacientes
# 3. Pasillos, habitaciones de pacientes, salas de descanso del personal y vestuarios
# 4. Puertas de pasillos
# 5. Servicios, salas de almacén, zonas exteriores con bancos, salas de espera sin asistentes
# ...
